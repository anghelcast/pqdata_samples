# %% [markdown]
# # PQ MEASUREMENTS DATA NOTEBOOK
#
# #### LOCATION: EDIFICIO 7 FIME
# #### START TIME: MAY 7TH 2022
# #### END TIME: MAY 14TH 2022
# #### POWER ANALYZER: CIRCUTOR MYEBOX 1500

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %%
xslx = pd.ExcelFile("PQDATA_1000KVA.xlsx")

df1= pd.read_excel(xslx, "10min")
df2= pd.read_excel(xslx, "5min")
df3= pd.read_excel(xslx, "harmonics")
df4= pd.read_excel(xslx, "unbalance")

# %%
df1.head()
# Out:
#                 Fecha  Current-A-x  Current-B-x  Current-C-x  ActivePower  \
# 0 2022-05-07 12:20:00      387.004      341.437      323.647          133
# 1 2022-05-07 12:30:00      411.966      371.381      349.453          142
# 2 2022-05-07 12:40:00      387.575      341.243      329.468          134
# 3 2022-05-07 12:50:00      402.057      357.965      338.975          139
# 4 2022-05-07 13:00:00      399.770      360.687      341.304          139
#
#      Freq  ReactivePower  PLT-A  PLT-B  PLT-C  ...  Volts-ab-x  Volts-bc-x  \
# 0  59.999             25    NaN    NaN    NaN  ...      223.32      223.93
# 1  59.995             31  0.544  0.210  0.190  ...      223.30      223.91
# 2  60.005             26  0.482  0.215  0.218  ...      223.68      224.28
# 3  60.003             28  0.439  0.200  0.202  ...      223.64      224.24
# 4  59.997             28  0.409  0.190  0.192  ...      223.27      223.98
#
#    Volts-ca-x  Current-A-h  Current-B-h  Current-C-h  Volts-ab-h  Volts-bc-h  \
# 0      222.79     6.450067     5.690617     5.394117     13399.2     13435.8
# 1      222.74     6.866100     6.189683     5.824217     13398.0     13434.6
# 2      223.03     6.459583     5.687383     5.491133     13420.8     13456.8
# 3      222.91     6.700950     5.966083     5.649583     13418.4     13454.4
# 4      222.72     6.662833     6.011450     5.688400     13396.2     13438.8
#
#    Volts-ca-h    %s
# 0     13367.4  13.6
# 1     13364.4  14.6
# 2     13381.8  13.7
# 3     13374.6  14.2
# 4     13363.2  14.2
#
# [5 rows x 24 columns]

# %%
df2.head()
# Out:
#                 Fecha  PF-inst  PF-min  PF-max  PF-inst-a  PF-min-a  PF-max-a
# 0 2022-05-07 12:25:00     0.98    0.97    0.98       0.98      0.97      0.98
# 1 2022-05-07 12:30:00     0.98    0.98    0.98       0.98      0.98      0.98
# 2 2022-05-07 12:35:00     0.97    0.97    0.98       0.97      0.97      0.98
# 3 2022-05-07 12:40:00     0.98    0.98    0.98       0.98      0.98      0.98
# 4 2022-05-07 12:45:00     0.98    0.98    0.99       0.98      0.98      0.99

# %%
df3.head()
# Out:
#    Order  a-perc-h  b-perc-h  c-perc-h
# 0      2  0.058871  0.038980  0.073817
# 1      3  0.353225  0.155919  0.147634
# 2      4  0.014718  0.012993  0.024606
# 3      5  0.588709  0.246871  0.578233
# 4      6  0.014718  0.000000  0.012303

# %%
df4.head()
# Out:
#                 Fecha  Current-A-h  Current-B-h  Current-C-h    i-beta  \
# 0 2022-05-07 12:20:00     6.450067     5.690617     5.394117  0.341246
# 1 2022-05-07 12:30:00     6.866100     6.189683     5.824217  0.339697
# 2 2022-05-07 12:40:00     6.459583     5.687383     5.491133  0.340291
# 3 2022-05-07 12:50:00     6.700950     5.966083     5.649583  0.340423
# 4 2022-05-07 13:00:00     6.662833     6.011450     5.688400  0.339279
#
#      %unb-iH  Volts-ab-h  Volts-bc-h  Volts-ca-h    v-beta   %unb-vH
# 0  11.026832     13399.2     13435.8     13367.4  0.333339  0.294959
# 1   9.865574     13398.0     13434.6     13364.4  0.333339  0.302596
# 2  10.324920     13420.8     13456.8     13381.8  0.333340  0.322737
# 3  10.424362     13418.4     13454.4     13374.6  0.333341  0.343919
# 4   9.529196     13396.2     13438.8     13363.2  0.333340  0.326678

# %% [markdown]
# # Frecuencia

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
freq= df1['Freq']
plt.plot(x1, freq, color='purple', label='Frecuencia (Hz)')

plt.title('Gráfico de Frecuencia')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia (Hz)')
plt.grid()

# %% [markdown]
# ## Cálculo de la frecuencia promedio

# %%
freq= df1['Freq']
freq.mean(axis= 'index')
# Out:
# 60.000443000000026

# %% [markdown]
# # Potencia activa KW

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
ap= df1['ActivePower']
plt.plot(x1, ap, color='purple', label='Potencia (kW)')

plt.title('Demanda de Potencia Activa Total (III)')
plt.xlabel('Fecha')
plt.ylabel('Demanda (kW)')
plt.grid()

# %% [markdown]
# ## Cálculo de potencia activa promedio

# %%
ap= df1['ActivePower']
ap.mean(axis= 'index')
# Out:
# 142.601

# %% [markdown]
# # Potencia reactiva KVAR

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
rp= df1['ReactivePower']
plt.plot(x1, rp, color='purple', label='Potencia Reactiva (kVAR)')

plt.title('Demanda de Potencia Reactiva Total (III)')
plt.xlabel('Fecha')
plt.ylabel('Demanda (kVAR)')
plt.grid()
plt.show()

# %% [markdown]
# ## Cálculo de potencia reactiva promedio

# %%
rp= df1['ReactivePower']
rp.mean(axis= 'index')
# Out:
# 39.099

# %% [markdown]
# # Potencia aparente

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
sp= df1['%s']
plt.plot(x1, sp, color='purple', label='Potencia Aparente (kVA)')

plt.title('Gráfico de Utilización del Transformador')
plt.xlabel('Fecha')
plt.ylabel('% de Utilización (kVA)')
plt.grid()
plt.show()

# %% [markdown]
# ## Porcentaje promedio de utilización (kVA)

# %%
sp= df1['%s']
sp.mean(axis= 'index')
# Out:
# 14.901800000000001

# %% [markdown]
# # Corrientes por fase en baja tension

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
cax= df1['Current-A-x']
cbx= df1['Current-B-x']
ccx= df1['Current-C-x']

plt.plot(x1, cax, color ='black', label='Fase A')
plt.plot(x1, cbx, color = 'firebrick', label='Fase B')
plt.plot(x1, ccx, color = 'blue', label= 'Fase C')

plt.title('Demanda de Corriente por Fase (Baja tension)')
plt.xlabel('Fecha')
plt.ylabel('Corriente eficaz (Amperes RMS)')
plt.grid()
plt.legend( shadow=True )
plt.show()

# %% [markdown]
# ## Corriente promedio de la fase A en BT

# %%
cax= df1['Current-A-x']

cax.mean(axis= 'index')
# Out:
# 401.00840999999906

# %% [markdown]
# ## Corriente promedio de la fase B en BT

# %%
cbx= df1['Current-B-x']

cbx.mean(axis= 'index')
# Out:
# 401.05620400000026

# %% [markdown]
# ## Corriente promedio de la fase C en BT

# %%
ccx= df1['Current-C-x']

ccx.mean(axis= 'index')
# Out:
# 361.6252080000004

# %% [markdown]
# # Corrientes por fase en media tension

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
cah= df1['Current-A-h']
cbh= df1['Current-B-h']
cch= df1['Current-C-h']

plt.plot(x1, cah, color ='black', label='Fase A')
plt.plot(x1, cbh, color = 'firebrick', label='Fase B')
plt.plot(x1, cch, color = 'blue', label= 'Fase C')

plt.title('Demanda de Corriente por Fase (Media tension)')
plt.xlabel('Fecha')
plt.ylabel('Corriente eficaz (Amperes RMS)')
plt.grid()
plt.legend( shadow=True )
plt.show()

# %% [markdown]
# ## Corriente promedio de la fase A en MT

# %%
cah= df1['Current-A-h']

cah.mean(axis= 'index')
# Out:
# 6.683473500000012

# %% [markdown]
# ## Corriente promedio de la fase B en MT

# %%
cbh= df1['Current-B-h']

cbh.mean(axis= 'index')
# Out:
# 6.684270066666664

# %% [markdown]
# ## Corriente promedio de la fase C en MT

# %%
cch= df1['Current-C-h']

cch.mean(axis= 'index')
# Out:
# 6.027086799999997

# %% [markdown]
# # Voltajes de línea en baja tension

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
vabx= df1['Volts-ab-x']
vbcx= df1['Volts-bc-x']
vcax= df1['Volts-ca-x']

plt.plot(x1, vabx, color ='black', label='Fase A')
plt.plot(x1, vbcx, color = 'firebrick', label='Fase B')
plt.plot(x1, vcax, color = 'blue', label= 'Fase C')

plt.title('Tendencia de Voltajes de Linea (Baja tension)')
plt.xlabel('Fecha')
plt.ylabel('Voltaje eficaz (Volts RMS)')
plt.grid()
plt.legend( shadow=True, loc='lower right' )
plt.show()

# %% [markdown]
# ## Voltaje de linea AB promedio en BT

# %%
vabx= df1['Volts-ab-x']
vabx.mean(axis= 'index')
# Out:
# 224.96681999999993

# %% [markdown]
# ## Voltaje de linea BC promedio en BT

# %%
vbcx= df1['Volts-bc-x']
vbcx.mean(axis= 'index')
# Out:
# 225.68522000000021

# %% [markdown]
# ## Voltaje de linea CA promedio en BT

# %%
vcax= df1['Volts-ca-x']
vcax.mean(axis= 'index')
# Out:
# 223.88466999999983

# %% [markdown]
# # Voltajes de línea en media tension

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
vabh= df1['Volts-ab-h']
vbch= df1['Volts-bc-h']
vcah= df1['Volts-ca-h']

plt.plot(x1, vabh, color ='black', label='Fase A')
plt.plot(x1, vbch, color = 'firebrick', label='Fase B')
plt.plot(x1, vcah, color = 'blue', label= 'Fase C')

plt.title('Tendencia de Voltajes de Linea (Media tension)')
plt.xlabel('Fecha')
plt.ylabel('Voltaje eficaz (Volts RMS)')
plt.grid()
plt.legend( shadow=True, loc='lower right' )
plt.show()

# %% [markdown]
# ## Voltaje de linea AB promedio en MT

# %%
vabh= df1['Volts-ab-h']
vabh.mean(axis= 'index')
# Out:
# 13498.009200000002

# %% [markdown]
# ## Voltaje de linea BC promedio en MT

# %%
vbch= df1['Volts-bc-h']
vbch.mean(axis= 'index')
# Out:
# 13541.113200000018

# %% [markdown]
# ## Voltaje de linea CA promedio en MT

# %%
vcah= df1['Volts-ca-h']
vcah.mean(axis= 'index')
# Out:
# 13433.080199999993

# %% [markdown]
# # Factor de potencia

# %%
df2.head()
# Out:
#                 Fecha  PF-inst  PF-min  PF-max  PF-inst-a  PF-min-a  PF-max-a
# 0 2022-05-07 12:25:00     0.98    0.97    0.98       0.98      0.97      0.98
# 1 2022-05-07 12:30:00     0.98    0.98    0.98       0.98      0.98      0.98
# 2 2022-05-07 12:35:00     0.97    0.97    0.98       0.97      0.97      0.98
# 3 2022-05-07 12:40:00     0.98    0.98    0.98       0.98      0.98      0.98
# 4 2022-05-07 12:45:00     0.98    0.98    0.99       0.98      0.98      0.99

# %%
plt.figure(figsize=(20,8))
x1= df2['Fecha']
pfi= df2['PF-inst-a']
pfmax= df2['PF-max-a']
pfmin= df2['PF-min-a']

plt.plot(x1, pfi, color='purple', label='FP instántaneo')
plt.plot(x1, pfmax, color='orange', label='FP máximo')
plt.plot(x1, pfmin, color='gray', label='FP mínimo')

plt.title('Tendencia de Factor de Potencia Total (III)')
plt.xlabel('Fecha')
plt.ylabel('Factor de Potencia')
plt.legend(loc='lower left',shadow=True)
plt.grid()

# %% [markdown]
# ## Factor de potencia instantaneo promedio

# %%
pfi= df2['PF-inst-a']

pfi.mean(axis='index')
# Out:
# 0.9678189094547519

# %% [markdown]
# ## Factor de potencia maximo promedio

# %%
pfmax= df2['PF-max-a']

pfmax.mean(axis='index')
# Out:
# 0.9730015007503969

# %% [markdown]
# ## Factor de potencia minimo promedio

# %%
pfmin= df2['PF-min-a']

pfmin.mean(axis='index')
# Out:
# 0.9630215107554045

# %% [markdown]
# ## Requerimiento de Factor de potencia de acuerdo al CDR

# %%
df2['PF-inst-a'].value_counts(bins=[0,0.949,0.99], normalize=True)
# Out:
# (0.949, 0.99]      0.854927
# (-0.001, 0.949]    0.144572
# Name: PF-inst-a, dtype: float64

# %%
df2['PF-max-a'].value_counts(bins=[0,0.949,0.99], normalize=True)
# Out:
# (0.949, 0.99]      0.889945
# (-0.001, 0.949]    0.064532
# Name: PF-max-a, dtype: float64

# %%
df2['PF-min-a'].value_counts(bins=[0,0.949,0.99], normalize=True)
# Out:
# (0.949, 0.99]      0.748374
# (-0.001, 0.949]    0.251626
# Name: PF-min-a, dtype: float64

# %% [markdown]
# # Flicker PST PLT

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
plta= df1['PLT-A']
pltb= df1['PLT-B']
pltc= df1['PLT-C']

plt.plot(x1, plta, color ='black', label='Fase A')
plt.plot(x1, pltb, color = 'firebrick', label='Fase B')
plt.plot(x1, pltc, color = 'blue', label= 'Fase C')

plt.title('Long-Term Flicker (PLT) por fase')
plt.xlabel('Fecha')
plt.ylabel('PLT')
plt.grid()
plt.legend( shadow=True, loc='upper right' )
plt.show()

# %% [markdown]
# ## Flicker PLT - A promedio

# %%
plta= df1['PLT-A']

plta.mean(axis='index')
# Out:
# 0.18707707707707705

# %% [markdown]
# ## Flicker PLT - B promedio

# %%
pltb= df1['PLT-B']

pltb.mean(axis='index')
# Out:
# 0.1908328328328329

# %% [markdown]
# ## Flicker PLT - C promedio

# %%
pltc= df1['PLT-C']

pltc.mean(axis='index')
# Out:
# 0.1947237237237235

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
psta= df1['PST-A']
pstb= df1['PST-B']
pstc= df1['PST-C']

plt.plot(x1, psta, color ='black', label='Fase A')
plt.plot(x1, pstb, color = 'firebrick', label='Fase B')
plt.plot(x1, pstc, color = 'blue', label= 'Fase C')

plt.title('Short-Term Flicker (PST) por fase')
plt.xlabel('Fecha')
plt.ylabel('PST')
plt.grid()
plt.legend( shadow=True, loc='upper right' )
plt.show()

# %% [markdown]
# ## Flicker PST - A promedio

# %%
psta= df1['PST-A']

psta.mean(axis='index')
# Out:
# 0.17918999999999952

# %% [markdown]
# ## Flicker PST - B promedio

# %%
pstb= df1['PST-B']

pstb.mean(axis='index')
# Out:
# 0.1832399999999995

# %% [markdown]
# ## Flicker PST - C promedio

# %%
pstc= df1['PST-C']

pstc.mean(axis='index')
# Out:
# 0.18927999999999956

# %% [markdown]
# # Desbalance de voltaje y corriente

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
iunbalance= df4['%unb-iH']

plt.plot(x1, iunbalance, color ='purple', label='Desbalance de corriente')

plt.title('Tendencia de Desbalance de Corriente')
plt.xlabel('Fecha')
plt.ylabel('% Desbalance')
plt.grid()
plt.show()

# %% [markdown]
# ## Promedio de desbalance de corriente

# %%
iunbalance= df4['%unb-iH']

iunbalance.mean(axis='index')
# Out:
# 8.628810323115802

# %%
plt.figure(figsize=(20,8))
x1= df1['Fecha']
vunbalance= df4['%unb-vH']

plt.plot(x1, vunbalance, color ='purple', label='Desbalance de voltaje')

plt.title('Tendencia de Desbalance de Voltaje ')
plt.xlabel('Fecha')
plt.ylabel('% Desbalance')
plt.grid()
plt.show()

# %% [markdown]
# ## Promedio de desbalance de voltaje

# %%
vunbalance= df4['%unb-vH']

vunbalance.mean(axis='index')
# Out:
# 0.4749813130899334

# %% [markdown]
# # Armonicos de corriente

# %%
plt.figure(figsize=(20,8))
orden= df3['Order']
aperch= df3['a-perc-h']
bperch= df3['b-perc-h']
cperch= df3['c-perc-h']

width=0.25

indx= np.arange(len(orden))

plt.bar(indx - width, aperch, width=width, color ='black', label='Fase A')
plt.bar(indx, bperch, width=width, color ='firebrick', label='Fase B')
plt.bar(indx + width, cperch, width=width, color ='blue', label='Fase C')


plt.title(' Componentes Armónicas de Corriente por Fase')
plt.xlabel('Orden de la Armónica')
plt.ylabel('% de IL')
plt.xticks(ticks=indx, labels=orden)

plt.grid()
plt.legend( shadow=True )
plt.show()
